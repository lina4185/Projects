# %%
# !pip install -r requirements.txt

# %%
# !python download_data.py --start 20250101 --end 20260421
# Out:
# >> Fetching CSI500 constituents...
#    500 constituents from CSI500 index.
# >> Full download from 20250101 to 20260421
# >> Fetching CSI500 index benchmark...
#    313 index rows.
# >> Fetching constituent OHLCV...
# ...
# 100%|█████████████████████████████████████████| 500/500 [06:16<00:00,  1.33it/s]
# >> Saved 155,784 rows across 499 stocks to data/prices.parquet
#    success: 499, failed: 1
# >> Saved 499 constituents to data/constituents.csv (filtered to downloaded)
#    dropped from universe (no price data): ['689009']

# %%
# !python baseline_xgboost.py --out submission.csv
# Out:
# >> Loading /Users/alin1234/Downloads/ml-competition-sp26-main/data/prices.parquet
#    155,784 rows, 499 stocks, dates 2025-01-02 to 2026-04-21
# >> Building features
#    train: 113,383 rows up to 2026-03-16
#    embargo: 5 trading days (discarded)
#    val:   4,983 rows from 2026-03-24
# >> Training XGBoost
#    validation rank IC: 0.1368
#    Top10 avg return: 0.0230
#    Top20 avg return: 0.0254
#    Top30 avg return: 0.0233
#    Top50 avg return: 0.0231
# >> Predicting portfolio
#    as of 2026-04-14, scoring 499 stocks
#
# Top 10 scores:
# stock_code
# 300751    3.612366
# 603179    2.762700
# 002153    2.436584
# 002044    2.394055
# 300390    2.321139
# 002558    2.301829
# 601212    2.300568
# 000426    2.216165
# 600141    2.203602
# 301498    2.195025
# Name: score, dtype: float32
#
# Top 10 weights:
# stock_code
# 300751    0.058146
# 603179    0.044959
# 002153    0.038723
# 002044    0.037834
# 300390    0.036259
# 002558    0.035830
# 601212    0.035802
# ...

# %%
# !python validate_submission.py submission.csv
# Out:
# OK: submission.csv passes all checks

# %%
# !python download_data.py --update --end 20260430
# Out:
# >> Fetching CSI500 constituents...
#    500 constituents from CSI500 index.
# >> Incremental update from 20260422 to 20260430
# >> Fetching CSI500 index benchmark...
#    319 index rows.
# >> Fetching constituent OHLCV...
# ...
# 100%|█████████████████████████████████████████| 500/500 [06:16<00:00,  1.33it/s]
# >> Saved 158,778 rows across 499 stocks to data/prices.parquet
#    success: 499, failed: 1
# >> Saved 499 constituents to data/constituents.csv (filtered to downloaded)
#    dropped from universe (no price data): ['689009']

# %%
# !python baseline_xgboost.py --out submission.csv
# Out:
# >> Loading /Users/alin1234/Downloads/ml-competition-sp26-main/data/prices.parquet
#    158,778 rows, 499 stocks, dates 2025-01-02 to 2026-04-29
# >> Building features
#    train: 116,373 rows up to 2026-03-24
#    embargo: 5 trading days (discarded)
#    val:   4,983 rows from 2026-04-01
# >> Training XGBoost
#    validation rank IC: 0.2667
#    Top10 avg return: 0.0107
#    Top20 avg return: 0.0052
#    Top30 avg return: 0.0028
#    Top50 avg return: 0.0014
# >> Running backtest on validation period
#
# Backtest summary:
# Mean return: 0.04247017013823874
# Std: 0.027935793998376326
# Num periods: 10
#
# >> Evaluating backtest
#
# Backtest performance:
# Mean portfolio return: 0.04247017013823874
# Mean index return:     0.03758324789556629
# Mean excess return:    0.004886922242672455
#
# Cumulative return:
# Portfolio: 0.5109338719596563
# Index:     0.44438397410951547
# Excess:    0.06654989785014087
#
# >> Generating submission for latest date
#
# Top 10 weights (submission):
# ...

# %%
# !python download_data.py --update --end 20260509
# Out:
# >> Fetching CSI500 constituents...
#    500 constituents from CSI500 index.
# >> Incremental update from 20260501 to 20260509
# >> Fetching CSI500 index benchmark...
#    323 index rows.
# >> Fetching constituent OHLCV...
# ...
# 100%|█████████████████████████████████████████| 500/500 [06:17<00:00,  1.33it/s]
# >> Saved 160,774 rows across 499 stocks to data/prices.parquet
#    success: 499, failed: 1
# >> Saved 499 constituents to data/constituents.csv (filtered to downloaded)
#    dropped from universe (no price data): ['689009']

# %%
# !python baseline_xgboost.py --out submission.csv
# Out:
# >> Loading /Users/alin1234/Downloads/ml-competition-sp26-main/data/prices.parquet
#    160,774 rows, 499 stocks, dates 2025-01-02 to 2026-05-08
# >> Building features
#    train: 115,874 rows up to 2026-03-23
#    embargo: 5 trading days (discarded)
#    val:   7,477 rows from 2026-03-31
# >> Training XGBoost
#    validation rank IC: 0.1509
#    Top10 avg return: -0.0029
#    Top20 avg return: 0.0061
#    Top30 avg return: 0.0064
#    Top50 avg return: 0.0067
# >> Running backtest on validation period
#
# Backtest summary:
# Mean return: 0.034782243900266095
# Std: 0.026397658011802033
# Num periods: 15
#
# >> Evaluating backtest
#
# Backtest performance:
# Mean portfolio return: 0.034782243900266095
# Mean index return:     0.028673872521173104
# Mean excess return:    0.006108371379092988
#
# Cumulative return:
# Portfolio: 0.66251775653088
# Index:     0.5233604391402451
# Excess:    0.13915731739063486
#
# >> Generating submission for latest date
#
# Top 10 weights (submission):
# ...

# %%
# !python validate_submission.py submission.csv
# Out:
# OK: submission.csv passes all checks
